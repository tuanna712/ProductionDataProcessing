# %%
import requests

API_URL = "http://0.0.0.0:3339/report"   
POSTGRES_DB = ""
POSTGRES_USER = ""
POSTGRES_PASSWORD = ""
HOST = 'host.docker.internal'
PORT = 5432

payload = {
    "query_date": "2025/05/02",
    "POSTGRES_DB": POSTGRES_DB,
    "POSTGRES_USER": POSTGRES_USER,
    "POSTGRES_PASSWORD": POSTGRES_PASSWORD,
    "HOST": HOST,
    "PORT": PORT
}

# --- Get DataFrame as JSON ---
resp_df = requests.post(f"{API_URL}/df", json=payload)
if resp_df.status_code == 200:
    data = resp_df.json()
    print("DataFrame JSON result:")
    print(data[:3])
else:
    print("Error:", resp_df.status_code, resp_df.text)

# # --- Get DataFrame as CSV ---
resp_csv = requests.post(f"{API_URL}/csv", json=payload)
if resp_csv.status_code == 200:
    with open("report.csv", "w", encoding="utf-8") as f:
        f.write(resp_csv.text)
    print("CSV file saved as report.csv")
else:
    print("Error:", resp_csv.status_code, resp_csv.text)
# Out:
# DataFrame JSON result:
# [{'Mỏ': 'Bạch Hổ & Rồng& 50%NR-ĐM', 'KHCP  (tr.tấn)': 2.6999999999999997, 'KHQT  (tr.tấn)': 2.8499999990000005, 'Tháng trước - Cộng dồn (ng.tấn)': 927.921, 'Tháng trước - %KHCP': 34.36744444444445, 'Tháng trước - %KHQT': 32.55863159037145, 'Tháng này - KHCP (ng.tấn)': 231.3, 'Tháng này - KHQT (ng.tấn)': 259.795791, 'Tháng này - Thực hiện (ng.tấn)': 15.414000000000001, 'Tháng này - %KHCP': 6.664072632944229, 'Tháng này - %KHQT': 5.933121526206712, 'SL hiện tại - Cộng dồn (ng.tấn)': 943.335, 'SL hiện tại - Cộng dồn (thùng)': 7036743.454, 'SL hiện tại - %KHCP': 0.3493833333333334, 'SL hiện tại - %KHQT': 0.3309947369582437, 'SL ngày (tấn)': 7849.0, 'SL ngày (thùng)': 58521.024000000005}, {'Mỏ': 'NR-ĐM (Zarubezhneft)', 'KHCP  (tr.tấn)': 0.0399, 'KHQT  (tr.tấn)': 0.042024001, 'Tháng trước - Cộng dồn (ng.tấn)': 14.545, 'Tháng trước - %KHCP': 36.45363408521303, 'Tháng trước - %KHQT': 34.61117374330921, 'Tháng này - KHCP (ng.tấn)': 3.234379, 'Tháng này - KHQT (ng.tấn)': 3.416775, 'Tháng này - Thực hiện (ng.tấn)': 0.23, 'Tháng này - %KHCP': 7.111102316704381, 'Tháng này - %KHQT': 6.731493879462358, 'SL hiện tại - Cộng dồn (ng.tấn)': 14.775, 'SL hiện tại - Cộng dồn (thùng)': 108389.40000000008, 'SL hiện tại - %KHCP': 0.3703007518796993, 'SL hiện tại - %KHQT': 0.3515848003144679, 'SL ngày (tấn)': 115.0, 'SL ngày (thùng)': 843.64}, {'Mỏ': 'Cond. Dinh Cố & GPP Ca Mau', 'KHCP  (tr.tấn)': 0.042880190000000006, 'KHQT  (tr.tấn)': 0.045000001000000005, 'Tháng trước - Cộng dồn (ng.tấn)': 19.525, 'Tháng trước - %KHCP': 45.53384674834695, 'Tháng trước - %KHQT': 43.38888792469137, 'Tháng này - KHCP (ng.tấn)': 3.4521819999999996, 'Tháng này - KHQT (ng.tấn)': 3.633712, 'Tháng này - Thực hiện (ng.tấn)': 0.328, 'Tháng này - %KHCP': 9.501237188537571, 'Tháng này - %KHQT': 9.026582183728376, 'SL hiện tại - Cộng dồn (ng.tấn)': 19.852999999999998, 'SL hiện tại - Cộng dồn (thùng)': 167360.78999999983, 'SL hiện tại - %KHCP': 0.46298768732134804, 'SL hiện tại - %KHQT': 0.4411777679738273, 'SL ngày (tấn)': 164.0, 'SL ngày (thùng)': 1382.52}]
# CSV file saved as report.csv

# %%
import pandas as pd
df = pd.DataFrame(data)
df
# Out:
#                             Mỏ  KHCP  (tr.tấn)  ...  SL ngày (tấn)  SL ngày (thùng)
# 0     Bạch Hổ & Rồng& 50%NR-ĐM        2.700000  ...    7849.000000     58521.024000
# 1         NR-ĐM (Zarubezhneft)        0.039900  ...     115.000000       843.640000
# 2   Cond. Dinh Cố & GPP Ca Mau        0.042880  ...     164.000000      1382.520000
# 3                     Đại Hùng        0.396000  ...    1115.803631      8296.000000
# 4                      PM3-CAA        0.383991  ...    1084.133333      8131.000000
# 5                        46 CN        0.015009  ...      49.866667       374.000000
# 6        Rạng Đông+Phương Đông        0.399868  ...    1199.742221      9100.000000
# 7    Ruby+Pearl+Topaz+ Diamond        0.294355  ...    1019.758065      7587.000000
# 8              STĐ+STV+STT+STN        1.195000  ...    3448.280516     26506.000000
# 9                  Cá Ngừ Vàng        0.128000  ...     362.820513      2830.000000
# 10              Tê  Giác Trắng        0.396000  ...    1305.178211      9704.000000
# 11               Chim Sáo+ Dừa        0.289000  ...    1017.254902      7782.000000
# 12            Lan Tây + Lan Đỏ        0.000000  ...      13.938257       120.000000
# 13       Rồng Đôi+Rồng Đôi Tây        0.022000  ...     103.172589       813.000000
# 14    Hải Sư Trắng +Hải Sư Đen        0.123000  ...     500.263852      3792.000000
# 15        Thăng Long + Đông Đô        0.134588  ...     373.856650      2725.000000
# 16        Hải Thạch + Mộc Tinh        0.123685  ...     694.899577      5259.000000
# 17                      Cá Tầm        0.152277  ...     463.000000      3370.640000
# 18                   Thiên Ưng        0.008800  ...      29.000000       243.206025
# 19        Sao Vàng -Đại Nguyệt        0.288372  ...    1274.611399     10332.000000
# 20           Nhenhesky (49%VN)        1.197857  ...    4051.000000     29248.220000
# 21                     Algeria        0.218330  ...     881.923077      6879.000000
#
# [22 rows x 17 columns]
