# %%
import requests

API_URL = "http://0.0.0.0:3339/report"   
POSTGRES_DB = "QLKTDB"
POSTGRES_USER = "dev"
POSTGRES_PASSWORD = "StR0&GP@sSW)R4"
HOST = 'host.docker.internal'
PORT = 5432

payload = {
    "query_date": "2025/03/02",
    "POSTGRES_DB": POSTGRES_DB,
    "POSTGRES_USER": POSTGRES_USER,
    "POSTGRES_PASSWORD": POSTGRES_PASSWORD,
    "HOST": HOST,
    "PORT": PORT
}

# %%
import pandas as pd
# --- Get DataFrame as JSON ---
resp_df = requests.post(f"{API_URL}/oilreport", json=payload)
if resp_df.status_code == 200:
    data = resp_df.json()
    print("DataFrame JSON result:")
    print(data[:3])
else:
    print("Error:", resp_df.status_code, resp_df.text)
daily_oil_report = pd.DataFrame(data)
daily_oil_report
# Out:
# DataFrame JSON result:
# [{'Mỏ': 'Bạch Hổ & Rồng& 50%NR-ĐM', 'KHCP  (tr.tấn)': 2.6999999999999997, 'KHQT  (tr.tấn)': 2.8499999990000005, 'Tháng trước - Cộng dồn (ng.tấn)': 452.366, 'Tháng trước - %KHCP': 16.7542962962963, 'Tháng trước - %KHQT': 15.872491233639467, 'Tháng này - KHCP (ng.tấn)': 234.6, 'Tháng này - KHQT (ng.tấn)': 242.12, 'Tháng này - Thực hiện (ng.tấn)': 15.641, 'Tháng này - %KHCP': 6.667092924126172, 'Tháng này - %KHQT': 6.4600198248802245, 'SL hiện tại - Cộng dồn (ng.tấn)': 468.007, 'SL hiện tại - Cộng dồn (thùng)': 3491792.4099999997, 'SL hiện tại - %KHCP': 0.17333592592592595, 'SL hiện tại - %KHQT': 0.1642129825137589, 'SL ngày (tấn)': 7851.0, 'SL ngày (thùng)': 58553.742}, {'Mỏ': 'NR-ĐM (Zarubezhneft)', 'KHCP  (tr.tấn)': 0.0399, 'KHQT  (tr.tấn)': 0.042024001, 'Tháng trước - Cộng dồn (ng.tấn)': 7.125, 'Tháng trước - %KHCP': 17.857142857142858, 'Tháng trước - %KHQT': 16.954596969479418, 'Tháng này - KHCP (ng.tấn)': 3.567247, 'Tháng này - KHQT (ng.tấn)': 3.4299999999999997, 'Tháng này - Thực hiện (ng.tấn)': 0.235, 'Tháng này - %KHCP': 6.587713158073999, 'Tháng này - %KHQT': 6.85131195335277, 'SL hiện tại - Cộng dồn (ng.tấn)': 7.36, 'SL hiện tại - Cộng dồn (thùng)': 53992.96000000001, 'SL hiện tại - %KHCP': 0.18446115288220552, 'SL hiện tại - %KHQT': 0.175138012204026, 'SL ngày (tấn)': 120.0, 'SL ngày (thùng)': 880.32}, {'Mỏ': 'Cond. Dinh Cố & GPP Ca Mau', 'KHCP  (tr.tấn)': 0.042880190000000006, 'KHQT  (tr.tấn)': 0.045000001000000005, 'Tháng trước - Cộng dồn (ng.tấn)': 9.455, 'Tháng trước - %KHCP': 22.049809014372368, 'Tháng trước - %KHQT': 21.01111064419754, 'Tháng này - KHCP (ng.tấn)': 4.350817, 'Tháng này - KHQT (ng.tấn)': 4.7299999999999995, 'Tháng này - Thực hiện (ng.tấn)': 0.34, 'Tháng này - %KHCP': 7.814624241837797, 'Tháng này - %KHQT': 7.18816067653277, 'SL hiện tại - Cộng dồn (ng.tấn)': 9.795, 'SL hiện tại - Cộng dồn (thùng)': 82571.84999999996, 'SL hiện tại - %KHCP': 0.22842715948786604, 'SL hiện tại - %KHQT': 0.2176666618296297, 'SL ngày (tấn)': 170.0, 'SL ngày (thùng)': 1433.1}]
#                             Mỏ  KHCP  (tr.tấn)  KHQT  (tr.tấn)  \
# 0     Bạch Hổ & Rồng& 50%NR-ĐM        2.700000        2.850000
# 1         NR-ĐM (Zarubezhneft)        0.039900        0.042024
# 2   Cond. Dinh Cố & GPP Ca Mau        0.042880        0.045000
# 3                     Đại Hùng        0.396000        0.447111
# 4                      PM3-CAA        0.383991        0.437987
# 5                        46 CN        0.015009        0.017120
# 6        Rạng Đông+Phương Đông        0.399868        0.422164
# 7    Ruby+Pearl+Topaz+ Diamond        0.294355        0.331000
# 8              STĐ+STV+STT+STN        1.195000        1.299192
# 9                  Cá Ngừ Vàng        0.128000        0.131054
# 10              Tê  Giác Trắng        0.396000        0.459521
# 11               Chim Sáo+ Dừa        0.289000        0.316758
# 12            Lan Tây + Lan Đỏ        0.000000        0.001102
# 13       Rồng Đôi+Rồng Đôi Tây        0.022000        0.027619
# 14    Hải Sư Trắng +Hải Sư Đen        0.123000        0.175290
# 15        Thăng Long + Đông Đô        0.134588        0.151200
# 16        Hải Thạch + Mộc Tinh        0.123685        0.200000
# 17                      Cá Tầm        0.152277        0.210326
# 18                   Thiên Ưng        0.008800        0.007050
# 19        Sao Vàng -Đại Nguyệt        0.288372        0.382497
# 20           Nhenhesky (49%VN)        1.197857        1.475000
# 21                     Algeria        0.218330        0.299000
#
#     Tháng trước - Cộng dồn (ng.tấn)  Tháng trước - %KHCP  Tháng trước - %KHQT  \
# 0                        452.366000            16.754296            15.872491
# 1                          7.125000            17.857143            16.954597
# 2                          9.455000            22.049809            21.011111
# 3                         58.113786            14.675199            12.997613
# 4                         69.682267            18.146868            15.909678
# 5                          2.716533            18.098872            15.867598
# 6                         69.695262            17.429564            16.509065
# 7                         60.823925            20.663470            18.375808
# 8                        198.235621            16.588755            15.258373
# 9                         21.700513            16.953526            16.558428
# 10                        82.047613            20.719094            17.855017
# 11                        65.194379            22.558609            20.581751
# 12                         0.597719             0.000000            54.236267
# 13                         5.848096            26.582258            21.174055
# 14                        29.930607            24.333827            17.074885
# 15                        26.477420            19.672876            17.511521
# 16                        29.347912            23.727936            14.673956
# 17                        24.068727            15.805937            11.443534
# 18                         2.152302            24.457980            30.529113
# 19                        48.275968            16.740867            12.621268
# 20                       232.826930            19.436959            15.784877
# 21                        50.959487            23.340590            17.043307
#
#     Tháng này - KHCP (ng.tấn)  Tháng này - KHQT (ng.tấn)  \
# 0                  234.600000                     242.12
# 1                    3.567247                       3.43
# 2                    4.350817                       4.73
# 3                   24.007739                      30.15
# 4                   33.771160                      37.27
# 5                    1.250784                       1.46
# 6                   33.701864                      35.90
# 7                   26.151176                      32.22
# 8                  104.026116                     113.41
# 9                   12.279154                      10.80
# 10                  35.897017                      41.46
# 11                  26.047210                      32.06
# 12                   0.000000                       0.50
# 13                   2.113582                       3.35
# 14                  11.251163                      14.75
# 15                  11.760156                      13.58
# 16                  10.028519                      16.86
# 17                  11.782413                      14.26
# 18                   0.925257                       1.15
# 19                  26.431351                      31.91
# 20                 101.148783                     124.90
# 21                  18.633631                      27.03
#
#     Tháng này - Thực hiện (ng.tấn)  Tháng này - %KHCP  Tháng này - %KHQT  \
# 0                        15.641000           6.667093           6.460020
# 1                         0.235000           6.587713           6.851312
# 2                         0.340000           7.814624           7.188161
# 3                         2.206590           9.191163           7.318708
# 4                         2.169867           6.425206           5.822019
# 5                         0.050800           4.061453           3.479452
# 6                         2.307601           6.847101           6.427857
# 7                         2.064651           7.895058           6.407978
# 8                         6.938149           6.669622           6.117758
# 9                         0.693718           5.649558           6.423314
# 10                        2.684062           7.477117           6.473859
# 11                        2.117124           8.128027           6.603631
# 12                        0.025570           0.000000           5.114016
# 13                        0.197970           9.366542           5.909539
# 14                        0.973747           8.654632           6.601673
# 15                        1.003445           8.532582           7.389138
# 16                        1.147463          11.441999           6.805830
# 17                        0.810909           6.882369           5.686600
# 18                        0.074400           8.041009           6.469565
# 19                        2.194424           8.302352           6.876916
# 20                        8.052000           7.960551           6.446757
# 21                        1.809872           9.712931           6.695789
#
#     SL hiện tại - Cộng dồn (ng.tấn)  SL hiện tại - Cộng dồn (thùng)  \
# 0                        468.007000                    3.491792e+06
# 1                          7.360000                    5.399296e+04
# 2                          9.795000                    8.257185e+04
# 3                         60.320377                    4.484820e+05
# 4                         71.852133                    5.388910e+05
# 5                          2.767333                    2.075500e+04
# 6                         72.002863                    5.464680e+05
# 7                         62.888575                    4.678910e+05
# 8                        205.173770                    1.574709e+06
# 9                         22.394231                    1.746750e+05
# 10                        84.731675                    6.299800e+05
# 11                        67.311503                    5.149330e+05
# 12                         0.623289                    5.366143e+03
# 13                         6.046066                    4.764300e+04
# 14                        30.904354                    2.342550e+05
# 15                        27.480865                    2.003050e+05
# 16                        30.495375                    2.307890e+05
# 17                        24.879636                    1.811238e+05
# 18                         2.226702                    1.867405e+04
# 19                        50.470392                    4.091130e+05
# 20                       240.878930                    1.739146e+06
# 21                        52.769359                    4.116010e+05
#
#     SL hiện tại - %KHCP  SL hiện tại - %KHQT  SL ngày (tấn)  SL ngày (thùng)
# 0              0.173336             0.164213    7851.000000     58553.742000
# 1              0.184461             0.175138     120.000000       880.320000
# 2              0.228427             0.217667     170.000000      1433.100000
# 3              0.152324             0.134911    1110.154674      8254.000000
# 4              0.187120             0.164051    1041.333333      7810.000000
# 5              0.184373             0.161643      28.533333       214.000000
# 6              0.180067             0.170557    1152.859524      8750.000000
# 7              0.213649             0.189996    1031.586022      7675.000000
# 8              0.171694             0.157924    3528.920894     27111.983572
# 9              0.174955             0.170878     341.025641      2660.000000
# 10             0.213969             0.184391    1341.089442      9971.000000
# 11             0.232912             0.212501    1058.431373      8097.000000
# 12             0.000000             0.565565      10.958606        94.347000
# 13             0.274821             0.218908      98.477157       776.000000
# 14             0.251255             0.176304     487.994723      3699.000000
# 15             0.204184             0.181752     501.996875      3659.000000
# 16             0.246557             0.152477     573.731501      4342.000000
# 17             0.163385             0.118291     412.727273      3004.654547
# 18             0.253034             0.315844      37.200000       311.974626
# 19             0.175018             0.131950    1101.899827      8932.000000
# 20             0.201092             0.163308    4026.000000     29067.720000
# 21             0.241696             0.176486     906.923077      7074.000000

# %%
import pandas as pd
# --- Get DataFrame as JSON ---
resp_df = requests.post(f"{API_URL}/gasreport", json=payload)
if resp_df.status_code == 200:
    data = resp_df.json()
    print("DataFrame JSON result:")
    print(data[:3])
else:
    print("Error:", resp_df.status_code, resp_df.text)
daily_gas_report = pd.DataFrame(data)
daily_gas_report
# Out:
# DataFrame JSON result:
# [{'Mỏ': 'Bạch Hổ+ Rồng', 'KHCP  (tr.m3)': '90.00', 'KHQT  (tr.m3)': '122.00', 'Tháng trước - Cộng dồn (tr.m3)': '23.43', 'Tháng trước - %KHCP': '26.04', 'Tháng trước - %KHQT': '19.21', 'Tháng này - KHCP (tr.m3)': '9.71', 'Tháng này - KHQT (tr.m3)': '8.09', 'Tháng này - Thực hiện (tr.m3)': '0.50', 'Tháng này - %KHCP': '5.17', 'Tháng này - %KHQT': '6.21', 'SL hiện tại - Cộng dồn (tr.m3)': '23.94', 'SL hiện tại - Cộng dồn (tr.ft3)': '845.29', 'SL hiện tại - %KHCP': '26.60', 'SL hiện tại - %KHQT': '19.62', 'SL ngày (tr.m3)': '0.36', 'SL ngày (tr.ft3)': '12.85'}, {'Mỏ': 'Tê Giác Trắng', 'KHCP  (tr.m3)': '34.53', 'KHQT  (tr.m3)': '34.53', 'Tháng trước - Cộng dồn (tr.m3)': '9.24', 'Tháng trước - %KHCP': '26.77', 'Tháng trước - %KHQT': '26.77', 'Tháng này - KHCP (tr.m3)': '3.33', 'Tháng này - KHQT (tr.m3)': '5.98', 'Tháng này - Thực hiện (tr.m3)': '0.37', 'Tháng này - %KHCP': '11.05', 'Tháng này - %KHQT': '6.15', 'SL hiện tại - Cộng dồn (tr.m3)': '9.61', 'SL hiện tại - Cộng dồn (tr.ft3)': '339.40', 'SL hiện tại - %KHCP': '27.83', 'SL hiện tại - %KHQT': '27.83', 'SL ngày (tr.m3)': '0.19', 'SL ngày (tr.ft3)': '6.60'}, {'Mỏ': 'Rạng Đông+Phương Đông', 'KHCP  (tr.m3)': '34.35', 'KHQT  (tr.m3)': '100.00', 'Tháng trước - Cộng dồn (tr.m3)': '10.42', 'Tháng trước - %KHCP': '30.35', 'Tháng trước - %KHQT': '10.42', 'Tháng này - KHCP (tr.m3)': '0.00', 'Tháng này - KHQT (tr.m3)': '3.90', 'Tháng này - Thực hiện (tr.m3)': '0.20', 'Tháng này - %KHCP': '0.00', 'Tháng này - %KHQT': '5.25', 'SL hiện tại - Cộng dồn (tr.m3)': '10.63', 'SL hiện tại - Cộng dồn (tr.ft3)': '375.32', 'SL hiện tại - %KHCP': '30.94', 'SL hiện tại - %KHQT': '10.63', 'SL ngày (tr.m3)': '0.10', 'SL ngày (tr.ft3)': '3.64'}]
#                               Mỏ KHCP  (tr.m3) KHQT  (tr.m3)  \
# 0                  Bạch Hổ+ Rồng         90.00        122.00
# 1                  Tê Giác Trắng         34.53         34.53
# 2          Rạng Đông+Phương Đông         34.35        100.00
# 3                 Chim Sáo+  Dừa        113.83        117.30
# 4                STĐ+STV+STT+STN        405.20        441.19
# 5                    Cá Ngừ Vàng         27.80         30.00
# 6                 Lan Tây+Lan Đỏ          0.00         30.81
# 7          Rồng Đôi+Rồng Đôi Tây        261.20        266.60
# 8   Lô PM3-CAA ( tổng khí về bờ)        992.00       1935.42
# 9       Hải Sư Trắng +Hải Sư Đen         23.00         38.00
# 10          Hải Thạch + Mộc Tinh        745.05       1060.00
# 11                     Thái Bình        154.94        170.00
# 12                     Thiên Ưng        150.00        165.00
# 13          Sao Vàng -Đại Nguyet       1476.23       1712.81
# 14                      Đại Hùng         85.00         93.00
# 15                        Cá Tầm          5.90         17.70
#
#    Tháng trước - Cộng dồn (tr.m3) Tháng trước - %KHCP Tháng trước - %KHQT  \
# 0                           23.43               26.04               19.21
# 1                            9.24               26.77               26.77
# 2                           10.42               30.35               10.42
# 3                           14.10               12.39               12.02
# 4                           34.46                8.50                7.81
# 5                            7.96               28.63               26.53
# 6                           22.40                0.00               72.70
# 7                           58.13               22.25               21.80
# 8                          296.81               29.92               15.34
# 9                            1.76                7.64                4.63
# 10                         139.09               18.67               13.12
# 11                          17.54               11.32               10.32
# 12                          25.61               17.07               15.52
# 13                         219.07               14.84               12.79
# 14                          16.34               19.22               17.56
# 15                           0.63               10.75                3.58
#
#    Tháng này - KHCP (tr.m3) Tháng này - KHQT (tr.m3)  \
# 0                      9.71                     8.09
# 1                      3.33                     5.98
# 2                      0.00                     3.90
# 3                      9.63                     6.94
# 4                     34.41                    35.34
# 5                      3.00                     5.28
# 6                      0.00                     8.41
# 7                     25.11                    26.94
# 8                     89.12                   173.03
# 9                      2.38                     0.70
# 10                    68.42                    90.69
# 11                    12.91                    11.31
# 12                    14.28                    14.45
# 13                   133.13                   144.39
# 14                     7.73                     8.99
# 15                     0.47                     0.44
#
#    Tháng này - Thực hiện (tr.m3) Tháng này - %KHCP Tháng này - %KHQT  \
# 0                           0.50              5.17              6.21
# 1                           0.37             11.05              6.15
# 2                           0.20              0.00              5.25
# 3                           0.46              4.78              6.63
# 4                           1.67              4.85              4.73
# 5                           0.09              2.96              1.68
# 6                           0.02              0.00              0.25
# 7                           1.23              4.89              4.55
# 8                           9.88             11.08              5.71
# 9                           0.07              2.97             10.11
# 10                          5.57              8.14              6.14
# 11                          0.71              5.46              6.23
# 12                          0.98              6.88              6.80
# 13                          9.91              7.44              6.86
# 14                          0.66              8.56              7.36
# 15                          0.03              6.05              6.41
#
#    SL hiện tại - Cộng dồn (tr.m3) SL hiện tại - Cộng dồn (tr.ft3)  \
# 0                           23.94                          845.29
# 1                            9.61                          339.40
# 2                           10.63                          375.32
# 3                           14.56                          514.13
# 4                           36.13                         1275.87
# 5                            8.05                          284.18
# 6                           22.42                          791.76
# 7                           59.36                         2096.15
# 8                          306.69                        10830.64
# 9                            1.83                           64.59
# 10                         144.66                         5108.55
# 11                          18.24                          644.22
# 12                          26.59                          938.94
# 13                         228.98                         8086.33
# 14                          17.00                          600.25
# 15                           0.66                           23.39
#
#    SL hiện tại - %KHCP SL hiện tại - %KHQT SL ngày (tr.m3) SL ngày (tr.ft3)
# 0                26.60               19.62            0.36            12.85
# 1                27.83               27.83            0.19             6.60
# 2                30.94               10.63            0.10             3.64
# 3                12.79               12.41            0.23             8.14
# 4                 8.92                8.19            1.05            37.00
# 5                28.95               26.82            0.05             1.67
# 6                 0.00               72.77            0.00             0.00
# 7                22.72               22.26            0.15             5.23
# 8                30.92               15.85            4.13           146.01
# 9                 7.95                4.81            0.04             1.30
# 10               19.42               13.65            2.56            90.37
# 11               11.77               10.73            0.34            11.90
# 12               17.73               16.11            0.49            17.34
# 13               15.51               13.37            4.95           174.91
# 14               20.00               18.28            0.33            11.80
# 15               11.23                3.74            0.01             0.50
