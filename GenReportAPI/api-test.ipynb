# %%
import requests

API_URL = "http://0.0.0.0:3339/report"   
POSTGRES_DB = "QLKTDB"
POSTGRES_USER = "dev"
POSTGRES_PASSWORD = "StR0&GP@sSW)R4"
HOST = 'host.docker.internal'
PORT = 5432

payload = {
    "query_date": "2025/06/02",
    "POSTGRES_DB": POSTGRES_DB,
    "POSTGRES_USER": POSTGRES_USER,
    "POSTGRES_PASSWORD": POSTGRES_PASSWORD,
    "HOST": HOST,
    "PORT": PORT
}

# %%
import pandas as pd
# --- Get DataFrame as JSON ---
resp_df = requests.post(f"{API_URL}/oilreport", json=payload)
if resp_df.status_code == 200:
    data = resp_df.json()
    print("DataFrame JSON result:")
    print(data[:3])
else:
    print("Error:", resp_df.status_code, resp_df.text)
daily_oil_report = pd.DataFrame(data)
daily_oil_report
# Out:
# DataFrame JSON result:
# [{'Mỏ': 'Bạch Hổ & Rồng& 50%NR-ĐM', 'KHCP  (tr.tấn)': '2.70', 'KHQT  (tr.tấn)': '2.85', 'Tháng trước - Cộng dồn (ng.tấn)': '1406.08', 'Tháng trước - %KHCP': '52.08', 'Tháng trước - %KHQT': '49.34', 'Tháng này - KHCP (ng.tấn)': '233.80', 'Tháng này - KHQT (ng.tấn)': '241.48', 'Tháng này - Thực hiện (ng.tấn)': '7.99', 'Tháng này - %KHCP': '3.42', 'Tháng này - %KHQT': '3.31', 'SL hiện tại - Cộng dồn (ng.tấn)': '1414.07', 'SL hiện tại - Cộng dồn (thùng)': '10546506.46', 'SL hiện tại - %KHCP': '0.52', 'SL hiện tại - %KHQT': '0.50', 'SL ngày (tấn)': '7992.00', 'SL ngày (thùng)': '59594.95', 'Dữ liệu cập nhật đến ngày': '01/07/2025'}, {'Mỏ': 'NR-ĐM (Zarubezhneft)', 'KHCP  (tr.tấn)': '0.04', 'KHQT  (tr.tấn)': '0.04', 'Tháng trước - Cộng dồn (ng.tấn)': '21.26', 'Tháng trước - %KHCP': '53.28', 'Tháng trước - %KHQT': '50.59', 'Tháng này - KHCP (ng.tấn)': '3.31', 'Tháng này - KHQT (ng.tấn)': '3.69', 'Tháng này - Thực hiện (ng.tấn)': '0.10', 'Tháng này - %KHCP': '3.02', 'Tháng này - %KHQT': '2.71', 'SL hiện tại - Cộng dồn (ng.tấn)': '21.36', 'SL hiện tại - Cộng dồn (thùng)': '156696.96', 'SL hiện tại - %KHCP': '0.54', 'SL hiện tại - %KHQT': '0.51', 'SL ngày (tấn)': '100.00', 'SL ngày (thùng)': '733.60', 'Dữ liệu cập nhật đến ngày': '01/07/2025'}, {'Mỏ': 'Cond. Dinh Cố & GPP Ca Mau', 'KHCP  (tr.tấn)': '0.04', 'KHQT  (tr.tấn)': '0.05', 'Tháng trước - Cộng dồn (ng.tấn)': '29.20', 'Tháng trước - %KHCP': '68.09', 'Tháng trước - %KHQT': '64.89', 'Tháng này - KHCP (ng.tấn)': '3.53', 'Tháng này - KHQT (ng.tấn)': '3.61', 'Tháng này - Thực hiện (ng.tấn)': '0.14', 'Tháng này - %KHCP': '3.94', 'Tháng này - %KHQT': '3.85', 'SL hiện tại - Cộng dồn (ng.tấn)': '29.34', 'SL hiện tại - Cộng dồn (thùng)': '247319.34', 'SL hiện tại - %KHCP': '0.68', 'SL hiện tại - %KHQT': '0.65', 'SL ngày (tấn)': '139.00', 'SL ngày (thùng)': '1171.77', 'Dữ liệu cập nhật đến ngày': '01/07/2025'}]
#                             Mỏ KHCP  (tr.tấn) KHQT  (tr.tấn)  \
# 0     Bạch Hổ & Rồng& 50%NR-ĐM           2.70           2.85
# 1         NR-ĐM (Zarubezhneft)           0.04           0.04
# 2   Cond. Dinh Cố & GPP Ca Mau           0.04           0.05
# 3                     Đại Hùng           0.40           0.45
# 4                      PM3-CAA           0.38           0.44
# 5                        46 CN           0.02           0.02
# 6        Rạng Đông+Phương Đông           0.40           0.42
# 7    Ruby+Pearl+Topaz+ Diamond           0.29           0.33
# 8              STĐ+STV+STT+STN           1.19           1.30
# 9                  Cá Ngừ Vàng           0.13           0.13
# 10              Tê  Giác Trắng           0.40           0.46
# 11               Chim Sáo+ Dừa           0.29           0.32
# 12            Lan Tây + Lan Đỏ           0.00           0.00
# 13       Rồng Đôi+Rồng Đôi Tây           0.02           0.03
# 14    Hải Sư Trắng +Hải Sư Đen           0.12           0.18
# 15        Thăng Long + Đông Đô           0.13           0.15
# 16        Hải Thạch + Mộc Tinh           0.12           0.20
# 17                      Cá Tầm           0.15           0.21
# 18                   Thiên Ưng           0.01           0.01
# 19        Sao Vàng -Đại Nguyệt           0.29           0.38
# 20           Nhenhesky (49%VN)           1.20           1.48
# 21                     Algeria           0.22           0.30
#
#    Tháng trước - Cộng dồn (ng.tấn) Tháng trước - %KHCP Tháng trước - %KHQT  \
# 0                          1406.08               52.08               49.34
# 1                            21.26               53.28               50.59
# 2                            29.20               68.09               64.89
# 3                           197.97               49.99               44.28
# 4                           209.48               54.55               47.83
# 5                             9.05               60.28               52.85
# 6                           212.86               53.23               50.42
# 7                           181.16               61.54               54.73
# 8                           637.87               53.38               49.10
# 9                            65.34               51.04               49.85
# 10                          243.11               61.39               52.90
# 11                          168.59               58.34               53.22
# 12                            2.38                0.00              215.64
# 13                           18.84               85.62               68.20
# 14                           93.34               75.89               53.25
# 15                           78.82               58.56               52.13
# 16                           92.41               74.72               46.21
# 17                           82.60               54.25               39.27
# 18                            5.99               68.11               85.01
# 19                          176.52               61.21               46.15
# 20                          725.78               60.59               49.21
# 21                          159.39               73.00               53.31
#
#    Tháng này - KHCP (ng.tấn) Tháng này - KHQT (ng.tấn)  \
# 0                     233.80                    241.48
# 1                       3.31                      3.69
# 2                       3.53                      3.61
# 3                      41.89                     44.50
# 4                      36.27                     42.70
# 5                       1.25                      1.73
# 6                      30.97                     31.41
# 7                      25.79                     25.79
# 8                     100.13                    111.22
# 9                      10.13                     10.24
# 10                     33.42                     36.83
# 11                     27.29                     26.33
# 12                      0.00                      0.00
# 13                      2.01                      2.30
# 14                     10.58                     15.91
# 15                     11.76                     12.25
# 16                     14.71                     23.70
# 17                     14.02                     19.99
# 18                      0.85                      0.44
# 19                     28.06                     38.22
# 20                    101.01                    123.54
# 21                     18.28                     24.39
#
#    Tháng này - Thực hiện (ng.tấn) Tháng này - %KHCP Tháng này - %KHQT  \
# 0                            7.99              3.42              3.31
# 1                            0.10              3.02              2.71
# 2                            0.14              3.94              3.85
# 3                            2.21              5.27              4.96
# 4                            1.10              3.03              2.58
# 5                            0.06              4.67              3.38
# 6                            1.23              3.96              3.91
# 7                            0.97              3.76              3.76
# 8                            3.46              3.45              3.11
# 9                            0.39              3.87              3.83
# 10                           1.29              3.87              3.51
# 11                           0.97              3.55              3.67
# 12                           0.00              0.00              0.00
# 13                           0.11              5.23              4.57
# 14                           0.52              4.91              3.27
# 15                           0.43              3.67              3.52
# 16                           0.44              2.98              1.85
# 17                           0.33              2.32              1.63
# 18                           0.04              4.15              8.15
# 19                           0.29              1.05              0.77
# 20                           4.04              4.00              3.27
# 21                           0.90              4.91              3.68
#
#    SL hiện tại - Cộng dồn (ng.tấn) SL hiện tại - Cộng dồn (thùng)  \
# 0                          1414.07                    10546506.46
# 1                            21.36                      156696.96
# 2                            29.34                      247319.34
# 3                           200.17                     1488293.00
# 4                           210.58                     1579380.00
# 5                             9.11                       68300.00
# 6                           214.09                     1624862.02
# 7                           182.13                     1355014.00
# 8                           641.33                     4923572.18
# 9                            65.73                      512682.00
# 10                          244.40                     1817126.00
# 11                          169.56                     1297126.00
# 12                            2.38                       20460.22
# 13                           18.94                      149254.00
# 14                           93.86                      711488.10
# 15                           79.25                      577661.00
# 16                           92.85                      702704.00
# 17                           82.93                      603725.37
# 18                            6.03                       50561.72
# 19                          176.81                     1433260.00
# 20                          729.82                     5269287.12
# 21                          160.29                     1250249.76
#
#    SL hiện tại - %KHCP SL hiện tại - %KHQT SL ngày (tấn) SL ngày (thùng)  \
# 0                 0.52                0.50       7992.00        59594.95
# 1                 0.54                0.51        100.00          733.60
# 2                 0.68                0.65        139.00         1171.77
# 3                 0.51                0.45       2205.51        16398.00
# 4                 0.55                0.48       1100.40         8253.00
# 5                 0.61                0.53         58.40          438.00
# 6                 0.54                0.51       1226.72         9310.00
# 7                 0.62                0.55        969.09         7210.00
# 8                 0.54                0.49       3458.33        26609.86
# 9                 0.51                0.50        392.05         3058.00
# 10                0.62                0.53       1293.48         9617.00
# 11                0.59                0.54        967.58         7402.00
# 12                0.00                2.16          0.00            0.00
# 13                0.86                0.69        105.08          828.00
# 14                0.76                0.54        519.92         3941.00
# 15                0.59                0.52        431.62         3146.00
# 16                0.75                0.46        438.69         3320.00
# 17                0.54                0.39        325.45         2369.31
# 18                0.69                0.86         35.50          297.72
# 19                0.61                0.46        294.35         2386.00
# 20                0.61                0.49       4040.54        29172.70
# 21                0.73                0.54        897.82         7003.00
#
#    Dữ liệu cập nhật đến ngày
# 0                 01/07/2025
# 1                 01/07/2025
# 2                 01/07/2025
# 3                 01/07/2025
# 4                 01/07/2025
# 5                 01/07/2025
# 6                 01/07/2025
# 7                 01/07/2025
# 8                 01/07/2025
# 9                 01/07/2025
# 10                01/07/2025
# 11                01/07/2025
# 12                01/07/2025
# 13                01/07/2025
# 14                01/07/2025
# 15                01/07/2025
# 16                01/07/2025
# 17                01/07/2025
# 18                01/07/2025
# 19                01/07/2025
# 20                01/07/2025
# 21                01/07/2025

# %%
import pandas as pd
# --- Get DataFrame as JSON ---
resp_df = requests.post(f"{API_URL}/gasreport", json=payload)
if resp_df.status_code == 200:
    data = resp_df.json()
    print("DataFrame JSON result:")
    print(data[:3])
else:
    print("Error:", resp_df.status_code, resp_df.text)
daily_gas_report = pd.DataFrame(data)
daily_gas_report
# Out:
# DataFrame JSON result:
# [{'Mỏ': 'Bạch Hổ+ Rồng', 'KHCP  (tr.m3)': '90.00', 'KHQT  (tr.m3)': '122.00', 'Tháng trước - Cộng dồn (tr.m3)': '48.70', 'Tháng trước - %KHCP': '54.11', 'Tháng trước - %KHQT': '39.91', 'Tháng này - KHCP (tr.m3)': '9.25', 'Tháng này - KHQT (tr.m3)': '12.84', 'Tháng này - Thực hiện (tr.m3)': '0.69', 'Tháng này - %KHCP': '7.42', 'Tháng này - %KHQT': '5.34', 'SL hiện tại - Cộng dồn (tr.m3)': '49.38', 'SL hiện tại - Cộng dồn (tr.ft3)': '1743.87', 'SL hiện tại - %KHCP': '54.87', 'SL hiện tại - %KHQT': '40.48', 'SL ngày (tr.m3)': '0.34', 'SL ngày (tr.ft3)': '12.11', 'Dữ liệu cập nhật đến ngày': '02/06/2025'}, {'Mỏ': 'Tê Giác Trắng', 'KHCP  (tr.m3)': '34.53', 'KHQT  (tr.m3)': '34.53', 'Tháng trước - Cộng dồn (tr.m3)': '27.79', 'Tháng trước - %KHCP': '80.48', 'Tháng trước - %KHQT': '80.48', 'Tháng này - KHCP (tr.m3)': '2.83', 'Tháng này - KHQT (tr.m3)': '2.25', 'Tháng này - Thực hiện (tr.m3)': '0.45', 'Tháng này - %KHCP': '16.05', 'Tháng này - %KHQT': '20.20', 'SL hiện tại - Cộng dồn (tr.m3)': '28.24', 'SL hiện tại - Cộng dồn (tr.ft3)': '997.43', 'SL hiện tại - %KHCP': '81.80', 'SL hiện tại - %KHQT': '81.80', 'SL ngày (tr.m3)': '0.23', 'SL ngày (tr.ft3)': '8.11', 'Dữ liệu cập nhật đến ngày': '02/06/2025'}, {'Mỏ': 'Rạng Đông+Phương Đông', 'KHCP  (tr.m3)': '34.35', 'KHQT  (tr.m3)': '100.00', 'Tháng trước - Cộng dồn (tr.m3)': '31.05', 'Tháng trước - %KHCP': '90.41', 'Tháng trước - %KHQT': '31.05', 'Tháng này - KHCP (tr.m3)': '0.06', 'Tháng này - KHQT (tr.m3)': '0.17', 'Tháng này - Thực hiện (tr.m3)': '0.65', 'Tháng này - %KHCP': '1059.73', 'Tháng này - %KHQT': '390.01', 'SL hiện tại - Cộng dồn (tr.m3)': '31.70', 'SL hiện tại - Cộng dồn (tr.ft3)': '1119.45', 'SL hiện tại - %KHCP': '92.30', 'SL hiện tại - %KHQT': '31.70', 'SL ngày (tr.m3)': '0.31', 'SL ngày (tr.ft3)': '10.81', 'Dữ liệu cập nhật đến ngày': '02/06/2025'}]
#                               Mỏ KHCP  (tr.m3) KHQT  (tr.m3)  \
# 0                  Bạch Hổ+ Rồng         90.00        122.00
# 1                  Tê Giác Trắng         34.53         34.53
# 2          Rạng Đông+Phương Đông         34.35        100.00
# 3                 Chim Sáo+  Dừa        113.83        117.30
# 4                STĐ+STV+STT+STN        405.20        441.19
# 5                    Cá Ngừ Vàng         27.80         30.00
# 6                 Lan Tây+Lan Đỏ          0.00         30.81
# 7          Rồng Đôi+Rồng Đôi Tây        261.20        266.60
# 8   Lô PM3-CAA ( tổng khí về bờ)        992.00       1935.42
# 9       Hải Sư Trắng +Hải Sư Đen         23.00         38.00
# 10          Hải Thạch + Mộc Tinh        745.05       1060.00
# 11                     Thái Bình        154.94        170.00
# 12                     Thiên Ưng        150.00        165.00
# 13          Sao Vàng -Đại Nguyet       1476.23       1712.81
# 14                      Đại Hùng         85.00         93.00
# 15                        Cá Tầm          5.90         17.70
#
#    Tháng trước - Cộng dồn (tr.m3) Tháng trước - %KHCP Tháng trước - %KHQT  \
# 0                           48.70               54.11               39.91
# 1                           27.79               80.48               80.48
# 2                           31.05               90.41               31.05
# 3                           36.00               31.63               30.69
# 4                          137.60               33.96               31.19
# 5                           24.37               87.67               81.24
# 6                           50.50                0.00              163.89
# 7                          146.85               56.22               55.08
# 8                          787.19               79.35               40.67
# 9                            7.73               33.62               20.35
# 10                         413.64               55.52               39.02
# 11                          52.71               34.02               31.01
# 12                          60.58               40.39               36.72
# 13                         663.68               44.96               38.75
# 14                          31.98               37.63               34.39
# 15                           1.73               29.39                9.79
#
#    Tháng này - KHCP (tr.m3) Tháng này - KHQT (tr.m3)  \
# 0                      9.25                    12.84
# 1                      2.83                     2.25
# 2                      0.06                     0.17
# 3                      3.40                     3.85
# 4                     33.30                    40.49
# 5                      1.20                     1.07
# 6                      0.00                     0.00
# 7                     23.01                    22.19
# 8                     86.73                   172.03
# 9                      2.07                     4.74
# 10                    54.23                    81.86
# 11                    12.91                    15.68
# 12                    13.28                    15.07
# 13                   129.22                   155.15
# 14                     8.80                     9.29
# 15                     0.47                     1.62
#
#    Tháng này - Thực hiện (tr.m3) Tháng này - %KHCP Tháng này - %KHQT  \
# 0                           0.69              7.42              5.34
# 1                           0.45             16.05             20.20
# 2                           0.65           1059.73            390.01
# 3                           0.42             12.44             10.98
# 4                           0.57              1.70              1.40
# 5                           0.13             10.83             12.15
# 6                           0.87              0.00              0.00
# 7                           2.69             11.69             12.13
# 8                          10.94             12.61              6.36
# 9                           0.34             16.42              7.18
# 10                          4.10              7.55              5.00
# 11                          0.66              5.12              4.21
# 12                          0.93              6.97              6.15
# 13                          9.91              7.67              6.39
# 14                          0.94             10.72             10.16
# 15                          0.02              4.29              1.24
#
#    SL hiện tại - Cộng dồn (tr.m3) SL hiện tại - Cộng dồn (tr.ft3)  \
# 0                           49.38                         1743.87
# 1                           28.24                          997.43
# 2                           31.70                         1119.45
# 3                           36.43                         1286.43
# 4                          138.17                         4879.33
# 5                           24.50                          865.31
# 6                           51.37                         1814.06
# 7                          149.54                         5280.80
# 8                          798.13                        28185.73
# 9                            8.07                          285.10
# 10                         417.74                        14752.17
# 11                          53.37                         1884.79
# 12                          61.51                         2172.10
# 13                         673.59                        23787.62
# 14                          32.93                         1162.75
# 15                           1.75                           61.91
#
#    SL hiện tại - %KHCP SL hiện tại - %KHQT SL ngày (tr.m3) SL ngày (tr.ft3)  \
# 0                54.87               40.48            0.34            12.11
# 1                81.80               81.80            0.23             8.11
# 2                92.30               31.70            0.31            10.81
# 3                32.00               31.06            0.19             6.60
# 4                34.10               31.32            0.28            10.00
# 5                88.14               81.68            0.06             2.27
# 6                 0.00              166.72            0.70            24.65
# 7                57.25               56.09            2.11            74.55
# 8                80.46               41.24            5.44           192.04
# 9                35.10               21.25            0.17             6.05
# 10               56.07               39.41            2.29            81.05
# 11               34.45               31.39            0.35            12.29
# 12               41.00               37.28            0.47            16.53
# 13               45.63               39.33            4.96           174.98
# 14               38.74               35.40            0.50            17.73
# 15               29.73                9.90            0.01             0.35
#
#    Dữ liệu cập nhật đến ngày
# 0                 02/06/2025
# 1                 02/06/2025
# 2                 02/06/2025
# 3                 02/06/2025
# 4                 02/06/2025
# 5                 02/06/2025
# 6                 02/06/2025
# 7                 02/06/2025
# 8                 02/06/2025
# 9                 02/06/2025
# 10                02/06/2025
# 11                02/06/2025
# 12                02/06/2025
# 13                02/06/2025
# 14                02/06/2025
# 15                02/06/2025
